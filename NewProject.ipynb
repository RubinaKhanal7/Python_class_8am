# %%
from bs4 import BeautifulSoup
import requests
url = BeautifulSoup('https://pages.daraz.com.np/wow/gcp/route/daraz/np/upr/router?hybrid=1&data_prefetch=true&prefetch_replace=1&at_iframe=1&wh_pid=%2Flazada%2Fchannel%2Fnp%2Fflashsale%2FeBQX2YfTXs&hide_h5_title=true&lzd_navbar_hidden=true&disable_pull_refresh=true&skuIds=175827499%2C178346169%2C182462327%2C120729754%2C133726847%2C127976746%2C174748988&spm=a2a0e.tm80335409.FlashSale.d_shopMore', 'html.parser')
soup = requests.get(url)
soup
# Out:
# <Response [200]>

# %%
code = BeautifulSoup(soup.text,"lxml")
code
# Out:
# <!DOCTYPE HTML>
# <html><head>
# <link href="//g.lazcdn.com/" importance="high" rel="preconnect"/><link href="//lzd-img-global.slatic.net/" importance="high" rel="preconnect"/><link href="//acs-m.daraz.com.np" rel="preconnect"/><link as="script" href="//g.lazcdn.com/res-d/alilog/mlog/aplus/202980191.js" rel="preload"/><link as="script" crossorigin="anonymous" href="//g.lazcdn.com/g/woodpeckerx/itrace-next/??itrace-jserror.iife.js,itrace-interface.iife.js,itrace-perf.iife.js,itrace-flow.iife.js,itrace-blank.iife.js,itrace-resource.iife.js,itrace.iife.js" rel="preload"/><link as="script" crossorigin="anonymous" href="https://g.lazcdn.com/res-o/lzdfe/lzd-h5-itrace/index-module.js" rel="preload"/><link as="script" crossorigin="anonymous" href="//g.lazcdn.com/res-o/lzd_sec/LWSC/index.js" rel="preload"/>
# <link as="font" crossorigin="anonymous" href="//g.lazcdn.com/g/lzd/assets/1.2.13/font/EuclidCircularA-Regular.woff2" rel="preload"/>
# ...

# %%
table_code = code.find_all("div", class_="item-list-content clearfix")
table_code
# Out:
# []
