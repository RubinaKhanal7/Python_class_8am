# %%
from bs4 import BeautifulSoup
import requests
url = BeautifulSoup('https://www.worldometers.info/coronavirus', 'html.parser')
soup = requests.get(url)
soup
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:404: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# <Response [200]>

# %%
code = BeautifulSoup(soup.text,"lxml")
code = code.find("table", class_="table table-bordered table-hover main_table_countries")
tr_code = code.find_all("tr")
tr_code
# Out:
# [<tr>
#  <th width="1%">#</th>
#  <th width="100">Country,<br/>Other</th>
#  <th width="20">Total<br/>Cases</th>
#  <th width="30">New<br/>Cases</th>
#  <th width="30">Total<br/>Deaths</th>
#  <th width="30">New<br/>Deaths</th>
#  <th width="30">Total<br/>Recovered</th>
#  <th width="30">New<br/>Recovered</th>
#  <th width="30">Active<br/>Cases</th>
#  <th width="30">Serious,<br/>Critical</th>
#  <th width="30">Tot Cases/<br/>1M pop</th>
#  <th width="30">Deaths/<br/>1M pop</th>
#  <th width="30">Total<br/>Tests</th>
#  <th width="30">Tests/<br/>
#  <nobr>1M pop</nobr>
#  </th>
#  <th width="30">Population</th>
#  <th style="display:none" width="30">Continent</th>
#  <th width="30">1 Case<br/>every X ppl</th><th width="30">1 Death<br/>every X ppl</th><th width="30">1 Test<br/>every X ppl</th>
#  <th width="30">New Cases/1M pop</th>
#  <th width="30">New Deaths/1M pop</th>
#  <th width="30">Active Cases/1M pop</th>
#  </tr>,
# ...

# %%
rows = []
for i in tr_code[1:]:
    tds = []
    for j in i:
        z = j.text.replace(" ","").replace('\n','')
        if z != "":
            tds.append(z)
    
    rows.append(tds)
rows
# Out:
# [['NorthAmerica',
#   '131,889,132',
#   '1,695,941',
#   '127,665,129',
#   '+350',
#   '2,528,062',
#   '6,095',
#   'NorthAmerica'],
#  ['Asia',
#   '221,500,265',
#   '1,553,662',
#   '205,673,091',
#   '14,273,512',
#   '14,733',
#   'Asia'],
#  ['Europe',
#   '253,406,198',
#   '2,101,824',
#   '248,754,104',
#   '+474',
#   '2,550,270',
#   '4,453',
#   'Europe'],
#  ['SouthAmerica',
#   '70,200,879',
#   '1,367,332',
#   '66,683,585',
#   '2,149,962',
#   '8,953',
#   'SouthAmerica'],
#  ['Oceania',
#   '14,895,771',
#   '33,015',
#   '14,752,388',
#   '110,368',
#   '31',
#   'Australia/Oceania'],
#  ['Africa', '12,860,924', '258,892', '12,090,808', '511,224', '529', 'Africa'],
#  ['721', '15', '706', '0', '0'],
#  ['World',
#   '704,753,890',
#   '0',
#   '7,010,681',
#   '0',
#   '675,619,811',
#   '+790',
#   '22,123,398',
#   '34,794',
#   '90,413',
#   '899.4',
#   'All'],
#  ['1',
#   'USA',
#   '111,820,082',
#   '1,219,487',
#   '109,814,428',
#   '786,167',
# ...

# %%
header = tr_code[0].text.split('\n')[1:-1]
rows = [row[:len(header)] + [""] * (len(header) - len(row)) for row in rows]

# %%
import pandas as pd

df = pd.DataFrame(rows,columns = header)
df
# Out:
#                 # Country,Other TotalCases     NewCases TotalDeaths  \
# 0    NorthAmerica   131,889,132  1,695,941  127,665,129        +350
# 1            Asia   221,500,265  1,553,662  205,673,091  14,273,512
# 2          Europe   253,406,198  2,101,824  248,754,104        +474
# 3    SouthAmerica    70,200,879  1,367,332   66,683,585   2,149,962
# 4         Oceania    14,895,771     33,015   14,752,388     110,368
# ..            ...           ...        ...          ...         ...
# 242        Total:    70,200,879  1,367,332   66,683,585   2,149,962
# 243        Total:    14,895,771     33,015   14,752,388     110,368
# 244        Total:    12,860,924    258,892   12,090,808     511,224
# 245        Total:           721         15          706           0
# 246        Total:   704,753,890          0    7,010,681           0
#
#        NewDeaths     TotalRecovered  NewRecovered ActiveCases  \
# 0      2,528,062              6,095  NorthAmerica
# ...

# %%
df.to_csv('worldometer_data.csv')

# %%
df['TotalCases'] = [float(i.replace(',','')) for i in df['TotalCases']]

# %%
df1 = df

# %%
df1 = df.sort_values(by=['TotalCases'], ascending = False).iloc[0:10]
df1
# Out:
#      # Country,Other   TotalCases   NewCases  TotalDeaths  NewDeaths  \
# 8    1           USA  111820082.0  1,219,487  109,814,428    786,167
# 9    2         India   45035393.0    533,570          N/A        N/A
# 10   3        France   40138560.0    167,642   39,970,918          0
# 11   4       Germany   38828995.0    183,027   38,240,600    405,368
# 12   5        Brazil   38743918.0    711,380   36,249,161  1,783,377
# 13   6       S.Korea   34571873.0     35,934   34,535,939          0
# 14   7         Japan   33803572.0     74,694          N/A        N/A
# 15   8         Italy   26723249.0    196,487   26,361,218    165,544
# 16   9            UK   24910387.0    232,112   24,678,275          0
# 17  10        Russia   24124215.0    402,756   23,545,818    175,641
#
#    TotalRecovered NewRecovered  ActiveCases Serious,Critical  ...  \
# 8             940      333,985        3,642    1,186,851,502  ...
# 9             N/A          N/A       32,016              379  ...
# ...

# %%
df1
# Out:
#      # Country,Other   TotalCases   NewCases  TotalDeaths  NewDeaths  \
# 8    1           USA  111820082.0  1,219,487  109,814,428    786,167
# 9    2         India   45035393.0    533,570          N/A        N/A
# 10   3        France   40138560.0    167,642   39,970,918          0
# 11   4       Germany   38828995.0    183,027   38,240,600    405,368
# 12   5        Brazil   38743918.0    711,380   36,249,161  1,783,377
# 13   6       S.Korea   34571873.0     35,934   34,535,939          0
# 14   7         Japan   33803572.0     74,694          N/A        N/A
# 15   8         Italy   26723249.0    196,487   26,361,218    165,544
# 16   9            UK   24910387.0    232,112   24,678,275          0
# 17  10        Russia   24124215.0    402,756   23,545,818    175,641
#
#    TotalRecovered NewRecovered  ActiveCases Serious,Critical  ...  \
# 8             940      333,985        3,642    1,186,851,502  ...
# 9             N/A          N/A       32,016              379  ...
# ...

# %%
import plotly.express as px

fig = px.bar(df1, x='Country,Other', y='TotalCases')
fig.show()
# Out:
# <div>                            <div id="05b61f4a-2471-4f04-98ef-56a6d9ce6264" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("05b61f4a-2471-4f04-98ef-56a6d9ce6264")) {                    Plotly.newPlot(                        "05b61f4a-2471-4f04-98ef-56a6d9ce6264",                        [{"alignmentgroup":"True","hovertemplate":"Country,Other=%{x}<br>TotalCases=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["USA","India","France","Germany","Brazil","S.Korea","Japan","Italy","UK","Russia"],"xaxis":"x","y":[111820082.0,45035393.0,40138560.0,38828995.0,38743918.0,34571873.0,33803572.0,26723249.0,24910387.0,24124215.0]
# ...

# %%
df1['ActiveCases'] = [float(i.replace(',','')) for i in df1['ActiveCases']]
df1['Serious,Critical'] = [float(i.replace(',','')) for i in df1['Serious,Critical']]

# %%
df1
# Out:
#      # Country,Other   TotalCases   NewCases  TotalDeaths  NewDeaths  \
# 8    1           USA  111820082.0  1,219,487  109,814,428    786,167
# 9    2         India   45035393.0    533,570          N/A        N/A
# 10   3        France   40138560.0    167,642   39,970,918          0
# 11   4       Germany   38828995.0    183,027   38,240,600    405,368
# 12   5        Brazil   38743918.0    711,380   36,249,161  1,783,377
# 13   6       S.Korea   34571873.0     35,934   34,535,939          0
# 14   7         Japan   33803572.0     74,694          N/A        N/A
# 15   8         Italy   26723249.0    196,487   26,361,218    165,544
# 16   9            UK   24910387.0    232,112   24,678,275          0
# 17  10        Russia   24124215.0    402,756   23,545,818    175,641
#
#    TotalRecovered NewRecovered  ActiveCases  Serious,Critical  ...  \
# 8             940      333,985       3642.0      1.186852e+09  ...
# 9             N/A          N/A      32016.0      3.790000e+02  ...
# ...

# %%
import plotly.graph_objects as go


fig = go.Figure(data=[
    go.Bar(name='Active Cases', x=df1['Country,Other'], y=df1['ActiveCases']),
    go.Bar(name='Serious or Critical', x=df1['Country,Other'], y=df1['Serious,Critical'])
])
fig.update_layout(barmode='group')
fig.show()
# Out:
# <div>                            <div id="711737ae-8fda-409b-b440-4656bc226f63" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("711737ae-8fda-409b-b440-4656bc226f63")) {                    Plotly.newPlot(                        "711737ae-8fda-409b-b440-4656bc226f63",                        [{"name":"Active Cases","x":["USA","India","France","Germany","Brazil","S.Korea","Japan","Italy","UK","Russia"],"y":[3642.0,32016.0,271490188.0,2182.0,3303.0,15804065.0,269169.0,3261.0,3389.0,2762.0],"type":"bar"},{"name":"Serious or Critical","x":["USA","India","France","Germany","Brazil","S.Korea","Japan","Italy","UK","Russia"],"y":[1186851502.0,379.0,4139547.0,122332384.0,63776166.0,307892.0,595.0,281126449.0,522526476.0,273400000.0],"type":"bar"}],            
# ...
